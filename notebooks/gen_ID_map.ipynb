# %%
import pandas as pd
from pathlib import Path
from pprint import pformat
from typing import Any

# %%
# This function takes a dictionary, write out as a module that can be imported later

def write_mapping_to_module(mapping: dict[Any, Any], variable_name: str, module_path: Path) -> None:
    """
    Writes a Python dictionary to a module file as a variable.

    Args:
        mapping (dict): The dictionary to write.
        variable_name (str): The variable name to assign in the module.
        module_path (Path): Path to the Python file to create/write.
    """
    # Ensure the directory exists
    module_path.parent.mkdir(parents=True, exist_ok=True)

    # Write the dictionary to the Python module
    with module_path.open("w", encoding="utf-8") as f:
        f.write(f"# Auto-generated mapping: {variable_name}\n")
        f.write("# Do not edit by hand\n\n")
        f.write(f"{variable_name} = ")
        f.write(pformat(mapping))
        f.write("\n")

# %%
url = "http://scdb.wustl.edu/documentation.php?var=justice"

# Read all tables from the page
tables = pd.read_html(url)

# Inspect how many tables were found
print(len(tables))

# Inspect all tables's shape to see which one has the info (looksl ike table 5)
for i, t in enumerate(tables):
    print(f"Table {i} shape:", t.shape)
print()
    
# The Justice ID table is the 5th one on the page
df = tables[5]

# rename the columns
df.columns = ["justice_id", "short_code", "full_text"]

print(df.tail())
# Out:
# 8
# Table 0 shape: (1, 2)
# Table 1 shape: (8, 5)
# Table 2 shape: (1, 4)
# Table 3 shape: (1, 2)
# Table 4 shape: (1, 3)
# Table 5 shape: (118, 3)
# Table 6 shape: (1, 4)
# Table 7 shape: (1, 4)
#
#      justice_id   short_code                                     full_text
# 113         114       EKagan      Kagan, Elena ( 08/07/2010 - 00/00/0000 )
# 114         115    NMGorsuch     Gorsuch, Neil ( 04/08/2017 - 00/00/0000 )
# 115         116  BMKavanaugh  Kavanaugh, Brett ( 10/06/2018 - 00/00/0000 )
# 116         117    ACBarrett      Barrett, Amy ( 10/27/2020 - 00/00/0000 )
# 117         118    KBJackson  Jackson, Ketanji ( 06/30/2022 - 00/00/0000 )

# %%
# map justice ID code to words

df["justice_name"] = (
    df["full_text"]
    .str.extract(r"^(.+?)\s*\(")[0]
)

JUSTICE_NAME_MAP = dict(zip(df["justice_id"], df["justice_name"]))

#print(JUSTICE_NAME_MAP)

# write this dictionary into a module for future use
write_mapping_to_module(JUSTICE_NAME_MAP, "JUSTICE_NAME_MAP", Path("../scdb_code_map/justice_code.py"))

# %%
# maps issue area code to words

ISSUE_AREA_MAP = {
    1: "Criminal Procedure",
    2: "Civil Rights",
    3: "First Amendment",
    4: "Due Process",
    5: "Privacy",
    6: "Attorneys",
    7: "Unions",
    8: "Economic Activity",
    9: "Judicial Power",
    10: "Federalism",
    11: "Interstate Relations",
    12: "Federal Taxation",
    13: "Miscellaneous",
    14: "Private Law"
}

write_mapping_to_module(ISSUE_AREA_MAP, "ISSUE_AREA_MAP", Path("../scdb_code_map/issueArea_code.py"))

# %%
# maps case disposition code to words

CASE_DISPOSITION_MAP = {
    1: "Affirmed",
    2: "Reversed",
    3: "Vacated",
    4: "Remanded",
    5: "Dismissed",
    6: "Other"
}

write_mapping_to_module(CASE_DISPOSITION_MAP, "CASE_DISPOSITION_MAP", Path("../scdb_code_map/caseDisposition_code.py"))

# %%
# maps decision direction code to words
DECISION_DIRECTION_MAP = {
    1: "Conservative",
    2: "Liberal",
    3: "Unclear"
}

def write_mapping_to_module(mapping: dict[Any, Any], variable_name: str, module_path: Path) -> None:
    """
    Writes a Python dictionary to a module file as a variable.

    Args:
        mapping (dict): The dictionary to write.
        variable_name (str): The variable name to assign in the module.
        module_path (Path): Path to the Python file to create/write.
    """
    # Ensure the directory exists
    module_path.parent.mkdir(parents=True, exist_ok=True)

    # Write the dictionary to the Python module
    with module_path.open("w", encoding="utf-8") as f:
        f.write(f"# Auto-generated mapping: {variable_name}\n")
        f.write("# Do not edit by hand\n\n")
        f.write(f"{variable_name} = ")
        f.write(pformat(mapping))
        f.write("\n")

write_mapping_to_module(DECISION_DIRECTION_MAP, "DECISION_DIRECTION_MAP", Path("../scdb_code_map/deciDirect_code.py"))

# %%
# map petitioner to words
PETITIONER_MAP = {
    0: "Unknown",
    1: "United States",
    2: "State Government",
    3: "Local Government",
    4: "Private Individual",
    5: "Business / Corporation",
    6: "Organization / Union",
    7: "Criminal Defendant",
    8: "Other",
    9: "Miscellaneous"
}

write_mapping_to_module(PETITIONER_MAP, "PETITIONER_MAP", Path("../scdb_code_map/petitioner_code.py"))

# %%
# map decision type to words

DECISION_TYPE_MAP = {
    1: "Opinion of the Court (signed majority opinion)",
    2: "Per curiam opinion (unsigned majority opinion)",
    3: "Plurality opinion",
    4: "No clear majority opinion",
    5: "Judgment of the Court",
    6: "Equally divided Court",
    7: "Decree (non-opinion disposition)"
}

write_mapping_to_module(DECISION_TYPE_MAP, "DECISION_TYPE_MAP", Path("../scdb_code_map/decisionType_code.py"))

# %%
# map lawSupp to words

LAW_SUPP_MAP = {
    # --- CONSTITUTIONAL ARTICLES (100-153) ---
    100: "Art. I, Sec. 1 (Delegation of Powers)",
    101: "Art. I, Sec. 10 (State Restrictions: Bills of Credit, etc.)",
    102: "Art. I, Sec. 2 (House Composition)",
    103: "Art. I, Sec. 4 (Elections)",
    105: "Art. I, Sec. 6 (Speech or Debate Clause)",
    106: "Art. I, Sec. 7 (Veto/Legislative Process)",
    107: "Art. I, Sec. 8, Cl. 1 (Taxing/General Welfare)",
    108: "Art. I, Sec. 8, Cl. 3 (Interstate Commerce)",
    110: "Art. I, Sec. 8, Cl. 4 (Bankruptcy/Naturalization)",
    111: "Art. I, Sec. 8, Cl. 11 (War Power)",
    120: "Art. I, Sec. 8, Cl. 18 (Necessary and Proper Clause)",
    121: "Art. I, Sec. 9, Cl. 2 (Habeas Corpus)",
    122: "Art. I, Sec. 9, Cl. 3 (Ex Post Facto/Bill of Attainder)",
    128: "Art. I, Sec. 10, Cl. 1 (Contract Clause)",
    130: "Art. II, Sec. 1 (Executive Power)",
    134: "Art. II, Sec. 2 (Commander in Chief)",
    135: "Art. II, Sec. 2, Cl. 2 (Appointments/Treaties)",
    136: "Art. III, Sec. 1 (Judicial Power)",
    139: "Art. III, Sec. 2 (Case or Controversy)",
    144: "Art. IV, Sec. 1 (Full Faith and Credit)",
    145: "Art. IV, Sec. 2, Cl. 1 (Privileges and Immunities)",
    148: "Art. VI, Cl. 2 (Supremacy Clause)",

    # --- AMENDMENTS (200-241) ---
    200: "Bill of Rights (General)",
    201: "1st Amend (Speech, Press, Assembly)",
    202: "1st Amend (Association)",
    203: "1st Amend (Free Exercise of Religion)",
    204: "1st Amend (Establishment Clause)",
    206: "4th Amend (Search and Seizure)",
    208: "5th Amend (Due Process)",
    210: "5th Amend (Miranda/Warnings)",
    211: "5th Amend (Self-incrimination)",
    212: "5th Amend (Takings Clause)",
    213: "5th Amend (Double Jeopardy)",
    214: "5th Amend (Grand Jury)",
    215: "6th Amend (Right to Counsel)",
    216: "6th Amend (Jury Trial)",
    217: "6th Amend (Confrontation Clause)",
    218: "6th Amend (Speedy Trial)",
    219: "6th Amend (Compulsory Process)",
    222: "8th Amend (Cruel and Unusual Punishment)",
    223: "8th Amend (Excessive Bail/Fines)",
    225: "11th Amend (State Sovereign Immunity)",
    229: "13th Amend (Slavery/Involuntary Servitude)",
    231: "14th Amend (Due Process)",
    232: "14th Amend (Equal Protection)",
    233: "14th Amend (Privileges or Immunities)",
    234: "14th Amend (Enforcement Power)",
    235: "15th Amend (Right to Vote)",
    238: "19th Amend (Women's Suffrage)",
    240: "24th Amend (Poll Tax)",

    # --- FEDERAL STATUTES (300-399) ---
    305: "Clean Air Act",
    306: "Administrative Procedure Act (APA)",
    312: "Civil Rights Act (1964)",
    314: "Civil Rights Act (1866/1871 - Sec 1983)",
    315: "Civil Rights Act (1965 - Voting Rights)",
    324: "ERISA (Pension/Benefits Law)",
    325: "Fair Labor Standards Act (FLSA)",
    327: "Federal Arbitration Act",
    332: "Federal Employers' Liability Act (FELA)",
    337: "Freedom of Information Act (FOIA)",
    342: "Immigration and Nationality Act",
    350: "National Labor Relations Act (NLRA)",
    355: "Occupational Safety and Health Act (OSHA)",
    363: "RICO Act",
    368: "Sherman Antitrust Act",
    369: "Clayton Antitrust Act",
    375: "Social Security Act",
    379: "Voting Rights Act of 1965",

    # --- COURT RULES & DOCTRINES (400-512) ---
    400: "Federal Rules of Civil Procedure",
    401: "Federal Rules of Criminal Procedure",
    402: "Federal Rules of Evidence",
    403: "Supreme Court Rules",
    500: "Abstention Doctrine",
    501: "Retroactive Application of Right",
    502: "Exclusionary Rule (4th Amend)",
    503: "Exclusionary Rule (Right to Counsel)",
    504: "Exclusionary Rule (Miranda)",
    505: "Harmless Error",
    506: "Res Judicata / Collateral Estoppel",
    508: "Writ Improvidently Granted (DIG)",
    509: "Treaty",
    510: "Interstate Compact",
    511: "Executive Order",
    512: "Territory Statute"
}

write_mapping_to_module(LAW_SUPP_MAP, "LAW_SUPP_MAP", Path("../scdb_code_map/lawSupp_code.py"))

# %%
# map lawType to words
LAW_TYPE_MAP = {
    1: "Constitution",
    2: "Constitutional Amendment",
    3: "Federal Statute",
    4: "Court Rules",
    5: "Other (e.g., Treaties, Executive Orders)",
    6: "State Statute",
    7: "State Constitutional Provision",
    8: "State Court Rule",
    9: "No Legal Provision (e.g., Common Law)"
}

write_mapping_to_module(LAW_TYPE_MAP, "LAW_TYPE_MAP", Path("../scdb_code_map/lawType_code.py"))
